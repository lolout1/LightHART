# %%
# !./train.sh
# Out:
# Initializing OptimizedTeacherModel with parameters:
# mocap_frames: 128, acc_frames: 128
# num_joints: 32, in_chans: 3, acc_coords: 4
# spatial_embed: 128
#
# Model initialization completed
# # Parameters: 7162888
# Model size : 6.83 MB
# Parameters:
# ...
